# %% [markdown]
# # Brain tumour MRI classification
#
# https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection
#
# See also: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %%
import cv2
import imutils
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %%
download_data = False

if download_data:
    # !wget https://github.com/MichaelAllen1966/1909_brain_tumour/raw/master/data.zip
    # !mkdir data
    # !unzip data.zip -d data

# %% [markdown]
# ## Load images

# %%
import cv2
import os

labels = ['yes', 'no']
X = []
y = []

for label in labels:
    path = './data/' + label
    for file in os.listdir(path):
                if not file.startswith('.'):
                    # Using 0 flag to read image in grayscale mode 
                    img = cv2.imread(path + '/' + file, 0)
                    X.append(img)
                    y.append(label)
                    
print(f'{len(X)} images loaded.')
# Out:
# 253 images loaded.

# %% [markdown]
# ## Crop images

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        #gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        #gray = cv2.GaussianBlur(gray, (5, 5), 0)
        gray = cv2.GaussianBlur(img, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return set_new

# %%
X = crop_imgs(X)

# %% [markdown]
# ## Resize images

# %%
IMG_SIZE = (224, 224)

# %%
def resize_imgs(set_name, img_size=(100,100)):
    """
    Resize
    """
    set_new = []
    for img in set_name:
        img = cv2.resize(
            img,
            dsize=img_size,
            interpolation=cv2.INTER_CUBIC
        )
        set_new.append(img)
    return np.array(set_new)

# %%
X = resize_imgs(X, (224,224))

# %% [markdown]
# ## Show image

# %%
def plot_image(img):
    fig, ax = plt.subplots(figsize=(3,3))
    ax.imshow(img, cmap='binary')
    ax.set_axis_off()
    plt.show()

# %%
# Show tumour (first image)
plot_image(X[0])

# %%
# Show  notumour (last image)
plot_image(X[-1])

# %% [markdown]
# ## Split into training and test

# %%
# Turn y into binary label
y = np.array([1 if label == 'yes' else 0 for label in y])
# Reshape X to have 1 channel
X = X.reshape(X.shape[0], IMG_SIZE[0], IMG_SIZE[1], 1)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
import tensorflow as tf

# %%
# ToDo Augment with keras ImageDataGenerator

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(224,224,1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      320
# _________________________________________________________________
# activation (Activation)      (None, 222, 222, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 109, 109, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 52, 52, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43264)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2768960
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,797,089
# Trainable params: 2,797,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.05,
        zoom_range=0.1,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='nearest')

train_generator = datagen.flow(X_train, y_train)

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=50,
                                                  restore_best_weights=True)

# Steps per epoch is number of batches generator produces 
batch_size = 16
steps_per_epoch = int(len(y_train) / batch_size) + 1

history = model.fit(train_generator,
                    steps_per_epoch=20,
                    epochs=250,
                    batch_size=batch_size,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping_cb],
                    verbose=1)
# Out:
# Epoch 1/250
# 20/20 [==============================] - 9s 435ms/step - loss: 53.3289 - accuracy: 0.5420 - val_loss: 0.6633 - val_accuracy: 0.6719
# Epoch 2/250
# 20/20 [==============================] - 2s 95ms/step - loss: 0.6438 - accuracy: 0.6498 - val_loss: 0.6273 - val_accuracy: 0.6719
# Epoch 3/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.6132 - accuracy: 0.6927 - val_loss: 0.5989 - val_accuracy: 0.6562
# Epoch 4/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.5567 - accuracy: 0.7353 - val_loss: 0.5371 - val_accuracy: 0.7031
# Epoch 5/250
# 20/20 [==============================] - 2s 89ms/step - loss: 1.4059 - accuracy: 0.6371 - val_loss: 0.5812 - val_accuracy: 0.7031
# Epoch 6/250
# 20/20 [==============================] - 2s 90ms/step - loss: 0.8543 - accuracy: 0.7436 - val_loss: 2.8836 - val_accuracy: 0.5625
# Epoch 7/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.6789 - accuracy: 0.7258 - val_loss: 0.7145 - val_accuracy: 0.5781
# Epoch 8/250
# 20/20 [==============================] - 2s 88ms/step - loss: 0.5731 - accuracy: 0.7448 - val_loss: 0.6709 - val_accuracy: 0.6562
# Epoch 9/250
# 20/20 [==============================] - 2s 82ms/step - loss: 0.5915 - accuracy: 0.7150 - val_loss: 0.7208 - val_accuracy: 0.6094
# Epoch 10/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.6475 - accuracy: 0.7369 - val_loss: 0.6006 - val_accuracy: 0.6875
# Epoch 11/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.9136 - accuracy: 0.7591 - val_loss: 0.6589 - val_accuracy: 0.7344
# Epoch 12/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.5966 - accuracy: 0.7787 - val_loss: 0.7155 - val_accuracy: 0.6094
# Epoch 13/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.5901 - accuracy: 0.7734 - val_loss: 0.6160 - val_accuracy: 0.6875
# Epoch 14/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.4479 - accuracy: 0.7845 - val_loss: 0.6408 - val_accuracy: 0.7031
# Epoch 15/250
# 20/20 [==============================] - 2s 94ms/step - loss: 0.4678 - accuracy: 0.8041 - val_loss: 0.6312 - val_accuracy: 0.7344
# Epoch 16/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.4670 - accuracy: 0.7845 - val_loss: 0.6051 - val_accuracy: 0.7656
# Epoch 17/250
# 20/20 [==============================] - 2s 93ms/step - loss: 0.5243 - accuracy: 0.7924 - val_loss: 0.6927 - val_accuracy: 0.7344
# Epoch 18/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.4271 - accuracy: 0.7803 - val_loss: 0.6036 - val_accuracy: 0.7188
# Epoch 19/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.5419 - accuracy: 0.7924 - val_loss: 0.6104 - val_accuracy: 0.7812
# Epoch 20/250
# 20/20 [==============================] - 2s 90ms/step - loss: 0.4011 - accuracy: 0.8320 - val_loss: 0.6711 - val_accuracy: 0.7656
# Epoch 21/250
# 20/20 [==============================] - 2s 85ms/step - loss: 0.4352 - accuracy: 0.8232 - val_loss: 0.5850 - val_accuracy: 0.7812
# Epoch 22/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.3611 - accuracy: 0.8479 - val_loss: 0.7112 - val_accuracy: 0.6250
# Epoch 23/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.3648 - accuracy: 0.8320 - val_loss: 0.5780 - val_accuracy: 0.7500
# Epoch 24/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.6499 - accuracy: 0.8248 - val_loss: 0.5363 - val_accuracy: 0.7344
# Epoch 25/250
# 20/20 [==============================] - 2s 82ms/step - loss: 0.3284 - accuracy: 0.8494 - val_loss: 0.6050 - val_accuracy: 0.7500
# Epoch 26/250
# 20/20 [==============================] - 2s 93ms/step - loss: 0.3699 - accuracy: 0.8510 - val_loss: 0.6479 - val_accuracy: 0.7812
# Epoch 27/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.3736 - accuracy: 0.8360 - val_loss: 3.7953 - val_accuracy: 0.6250
# Epoch 28/250
# 20/20 [==============================] - 2s 88ms/step - loss: 0.5333 - accuracy: 0.8352 - val_loss: 0.6213 - val_accuracy: 0.7188
# Epoch 29/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.3592 - accuracy: 0.8463 - val_loss: 0.7170 - val_accuracy: 0.7500
# Epoch 30/250
# 20/20 [==============================] - 2s 85ms/step - loss: 0.3387 - accuracy: 0.8519 - val_loss: 0.8372 - val_accuracy: 0.7500
# Epoch 31/250
# 20/20 [==============================] - 2s 80ms/step - loss: 0.3675 - accuracy: 0.8700 - val_loss: 0.6193 - val_accuracy: 0.8125
# Epoch 32/250
# 20/20 [==============================] - 2s 88ms/step - loss: 0.2712 - accuracy: 0.8906 - val_loss: 0.7372 - val_accuracy: 0.7500
# Epoch 33/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.2729 - accuracy: 0.8822 - val_loss: 0.5696 - val_accuracy: 0.7656
# Epoch 34/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.3090 - accuracy: 0.8653 - val_loss: 0.6787 - val_accuracy: 0.7500
# Epoch 35/250
# 20/20 [==============================] - 2s 90ms/step - loss: 0.4412 - accuracy: 0.8748 - val_loss: 0.5337 - val_accuracy: 0.7812
# Epoch 36/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.2369 - accuracy: 0.9013 - val_loss: 0.5741 - val_accuracy: 0.7344
# Epoch 37/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.2655 - accuracy: 0.8891 - val_loss: 3.6016 - val_accuracy: 0.6094
# Epoch 38/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.3897 - accuracy: 0.8716 - val_loss: 0.6706 - val_accuracy: 0.7969
# Epoch 39/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.2427 - accuracy: 0.8965 - val_loss: 0.5994 - val_accuracy: 0.7969
# Epoch 40/250
# 20/20 [==============================] - 2s 90ms/step - loss: 0.2354 - accuracy: 0.9033 - val_loss: 0.5145 - val_accuracy: 0.7344
# Epoch 41/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.2329 - accuracy: 0.9065 - val_loss: 0.5583 - val_accuracy: 0.7500
# Epoch 42/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.3003 - accuracy: 0.8758 - val_loss: 0.5009 - val_accuracy: 0.7656
# Epoch 43/250
# 20/20 [==============================] - 2s 94ms/step - loss: 0.2601 - accuracy: 0.9049 - val_loss: 0.5818 - val_accuracy: 0.7812
# Epoch 44/250
# 20/20 [==============================] - 2s 98ms/step - loss: 0.2439 - accuracy: 0.9049 - val_loss: 1.1068 - val_accuracy: 0.7656
# Epoch 45/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.2504 - accuracy: 0.8917 - val_loss: 0.6134 - val_accuracy: 0.7656
# Epoch 46/250
# 20/20 [==============================] - 2s 101ms/step - loss: 0.2187 - accuracy: 0.9160 - val_loss: 0.6165 - val_accuracy: 0.7656
# Epoch 47/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.2582 - accuracy: 0.9081 - val_loss: 0.7689 - val_accuracy: 0.7500
# Epoch 48/250
# 20/20 [==============================] - 2s 90ms/step - loss: 0.1674 - accuracy: 0.9347 - val_loss: 1.0418 - val_accuracy: 0.7031
# Epoch 49/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2494 - accuracy: 0.9223 - val_loss: 0.6895 - val_accuracy: 0.6719
# Epoch 50/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.2575 - accuracy: 0.8938 - val_loss: 0.6947 - val_accuracy: 0.6719
# Epoch 51/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2027 - accuracy: 0.9140 - val_loss: 0.9939 - val_accuracy: 0.6719
# Epoch 52/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1991 - accuracy: 0.9208 - val_loss: 0.8771 - val_accuracy: 0.7344
# Epoch 53/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2185 - accuracy: 0.9160 - val_loss: 0.7046 - val_accuracy: 0.7500
# Epoch 54/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.2127 - accuracy: 0.9299 - val_loss: 1.0492 - val_accuracy: 0.7031
# Epoch 55/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.2115 - accuracy: 0.9287 - val_loss: 0.6906 - val_accuracy: 0.7344
# Epoch 56/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.1778 - accuracy: 0.9429 - val_loss: 0.6053 - val_accuracy: 0.7969
# Epoch 57/250
# 20/20 [==============================] - 2s 88ms/step - loss: 0.2005 - accuracy: 0.9252 - val_loss: 0.7810 - val_accuracy: 0.6875
# Epoch 58/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.1818 - accuracy: 0.9477 - val_loss: 0.7505 - val_accuracy: 0.7969
# Epoch 59/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1970 - accuracy: 0.9176 - val_loss: 0.7493 - val_accuracy: 0.7812
# Epoch 60/250
# 20/20 [==============================] - 2s 91ms/step - loss: 0.1686 - accuracy: 0.9347 - val_loss: 1.0504 - val_accuracy: 0.7656
# Epoch 61/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.2126 - accuracy: 0.9192 - val_loss: 0.7162 - val_accuracy: 0.7500
# Epoch 62/250
# 20/20 [==============================] - 2s 93ms/step - loss: 0.1503 - accuracy: 0.9414 - val_loss: 0.6224 - val_accuracy: 0.7812
# Epoch 63/250
# 20/20 [==============================] - 2s 93ms/step - loss: 0.1903 - accuracy: 0.9363 - val_loss: 0.6822 - val_accuracy: 0.7656
# Epoch 64/250
# 20/20 [==============================] - 2s 82ms/step - loss: 0.1133 - accuracy: 0.9509 - val_loss: 1.5510 - val_accuracy: 0.7188
# Epoch 65/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1696 - accuracy: 0.9477 - val_loss: 1.1042 - val_accuracy: 0.7969
# Epoch 66/250
# 20/20 [==============================] - 2s 82ms/step - loss: 0.1725 - accuracy: 0.9347 - val_loss: 1.3584 - val_accuracy: 0.7656
# Epoch 67/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.1671 - accuracy: 0.9414 - val_loss: 0.8414 - val_accuracy: 0.7812
# Epoch 68/250
# 20/20 [==============================] - 2s 88ms/step - loss: 0.1967 - accuracy: 0.9255 - val_loss: 0.8986 - val_accuracy: 0.7812
# Epoch 69/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1945 - accuracy: 0.9315 - val_loss: 1.0703 - val_accuracy: 0.7656
# Epoch 70/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.1346 - accuracy: 0.9429 - val_loss: 1.0690 - val_accuracy: 0.7500
# Epoch 71/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.1243 - accuracy: 0.9540 - val_loss: 0.6981 - val_accuracy: 0.8125
# Epoch 72/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1518 - accuracy: 0.9427 - val_loss: 0.8470 - val_accuracy: 0.7500
# Epoch 73/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1407 - accuracy: 0.9509 - val_loss: 0.5841 - val_accuracy: 0.7500
# Epoch 74/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.1317 - accuracy: 0.9588 - val_loss: 1.0328 - val_accuracy: 0.7969
# Epoch 75/250
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0982 - accuracy: 0.9554 - val_loss: 0.9833 - val_accuracy: 0.7812
# Epoch 76/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.4041 - accuracy: 0.9525 - val_loss: 0.7746 - val_accuracy: 0.7969
# Epoch 77/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.1171 - accuracy: 0.9556 - val_loss: 0.7399 - val_accuracy: 0.7812
# Epoch 78/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0740 - accuracy: 0.9713 - val_loss: 2.3224 - val_accuracy: 0.7031
# Epoch 79/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0967 - accuracy: 0.9667 - val_loss: 1.5526 - val_accuracy: 0.7344
# Epoch 80/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1958 - accuracy: 0.9461 - val_loss: 1.0923 - val_accuracy: 0.7812
# Epoch 81/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.1051 - accuracy: 0.9602 - val_loss: 1.4917 - val_accuracy: 0.7656
# Epoch 82/250
# 20/20 [==============================] - 2s 85ms/step - loss: 0.3248 - accuracy: 0.9287 - val_loss: 1.1951 - val_accuracy: 0.7344
# Epoch 83/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1056 - accuracy: 0.9667 - val_loss: 1.2785 - val_accuracy: 0.7500
# Epoch 84/250
# 20/20 [==============================] - 2s 84ms/step - loss: 0.1172 - accuracy: 0.9570 - val_loss: 1.1266 - val_accuracy: 0.8125
# Epoch 85/250
# 20/20 [==============================] - 2s 86ms/step - loss: 0.1407 - accuracy: 0.9604 - val_loss: 1.1929 - val_accuracy: 0.7656
# Epoch 86/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.1035 - accuracy: 0.9683 - val_loss: 1.3287 - val_accuracy: 0.7812
# Epoch 87/250
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0909 - accuracy: 0.9682 - val_loss: 1.0743 - val_accuracy: 0.7656
# Epoch 88/250
# 20/20 [==============================] - 2s 94ms/step - loss: 0.1785 - accuracy: 0.9382 - val_loss: 1.4086 - val_accuracy: 0.7656
# Epoch 89/250
# 20/20 [==============================] - 2s 83ms/step - loss: 0.1416 - accuracy: 0.9556 - val_loss: 1.3067 - val_accuracy: 0.7344
# Epoch 90/250
# 20/20 [==============================] - 2s 89ms/step - loss: 0.1065 - accuracy: 0.9666 - val_loss: 0.9707 - val_accuracy: 0.7344
# Epoch 91/250
# 20/20 [==============================] - 2s 87ms/step - loss: 0.3686 - accuracy: 0.9223 - val_loss: 0.9044 - val_accuracy: 0.7656
# Epoch 92/250
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0742 - accuracy: 0.9731 - val_loss: 1.3042 - val_accuracy: 0.7812

# %%
history_dict = history.history

import matplotlib.pyplot as plt
# %matplotlib inline

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Test accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
probability = model.predict(X_test)
y_pred_test = probability >= 0.5
y_pred_test = y_pred_test.flatten()
accuracy_test = np.mean(y_pred_test == y_test)

# %%
accuracy_test
# Out:
# 0.765625

# %% [markdown]
# # Show an example of a missed tumour

# %%
# Get misseed tumours

missed = (y_pred_test == 0) & (y_test == 1)

# %%
missed_index = [i for i in range(len(missed)) if missed[i]]
missed_index
# Out:
# [0, 7, 18, 30, 37, 53, 54]

# %%
example = X_test[missed_index[0]]
example = example.reshape(example.shape[0], example.shape[1])

# %%
plot_image(example)

# %% [markdown]
# ## Show positive rates

# %%
y_test.mean()
# Out:
# 0.5625

# %%
y_pred_test.mean()
# Out:
# 0.578125

# %% [markdown]
# ## Some thing To Try .....
#
#
# * More accuracy measurement (e.g. sensitivity/specificity)
# * Plot a range of positve and negative images
# * ROC
# * Try changing net parameters, layers
# * Change image resolution
# * Transfer learning, e.g. see https://www.kaggle.com/ruslankl/brain-tumor-detection-v1-0-cnn-vgg-16
